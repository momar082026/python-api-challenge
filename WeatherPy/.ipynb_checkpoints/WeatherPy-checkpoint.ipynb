# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 591

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = "http://api.openweathermap.org/data/2.5/weather"
 
# Define an empty list to fetch the weather data for each city
city_data = []
 
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
 
# Create counters
record_count = 1
set_count = 1
 
# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
 
    # Create endpoint URL with each city
    city_url = f"{base_url}?q={city}&appid={weather_api_key}&units=metric"
 
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
 
    # Add 1 to the record count
    record_count += 1
 
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
 
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
 
        # Append the City information into city_data list
        city_data.append({"City": city,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date})
 
    except:
        print("City not found. Skipping...")
        pass
 
    # Pause between API calls to avoid rate limiting
    time.sleep(1)


# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | el bauga
# Processing Record 3 of Set 1 | bykovo
# Processing Record 4 of Set 1 | arlington
# Processing Record 5 of Set 1 | ploudalmezeau
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | invercargill
# Processing Record 9 of Set 1 | grytviken
# Processing Record 10 of Set 1 | diamante
# Processing Record 11 of Set 1 | road town
# Processing Record 12 of Set 1 | mili
# Processing Record 13 of Set 1 | buka
# Processing Record 14 of Set 1 | whitehorse
# Processing Record 15 of Set 1 | puerto aysen
# Processing Record 16 of Set 1 | waitangi
# Processing Record 17 of Set 1 | port lincoln
# Processing Record 18 of Set 1 | yuzhno-kurilsk
# Processing Record 19 of Set 1 | manokwari
# Processing Record 20 of Set 1 | sarny
# Processing Record 21 of Set 1 | polyarnyy
# Processing Record 22 of Set 1 | inari
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | klaksvik
# Processing Record 25 of Set 1 | murghob
# Processing Record 26 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 27 of Set 1 | udachny
# Processing Record 28 of Set 1 | vilyuchinsk
# Processing Record 29 of Set 1 | port augusta
# Processing Record 30 of Set 1 | fale old settlement
# Processing Record 31 of Set 1 | kish
# Processing Record 32 of Set 1 | edinburgh of the seven seas
# Processing Record 33 of Set 1 | isafjordur
# Processing Record 34 of Set 1 | olonkinbyen
# Processing Record 35 of Set 1 | mammoth lakes
# Processing Record 36 of Set 1 | juneau
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | bethel
# Processing Record 40 of Set 1 | anadyr
# Processing Record 41 of Set 1 | port mathurin
# Processing Record 42 of Set 1 | kavieng
# Processing Record 43 of Set 1 | stanley
# Processing Record 44 of Set 1 | puerto natales
# Processing Record 45 of Set 1 | longyearbyen
# Processing Record 46 of Set 1 | mitu
# Processing Record 47 of Set 1 | saint-joseph
# Processing Record 48 of Set 1 | newman
# Processing Record 49 of Set 1 | sumbawa besar
# Processing Record 50 of Set 1 | turpan
# Processing Record 0 of Set 2 | cedeira
# Processing Record 1 of Set 2 | fort st. john
# Processing Record 2 of Set 2 | sisimiut
# Processing Record 3 of Set 2 | kongoussi
# Processing Record 4 of Set 2 | lakatoro
# Processing Record 5 of Set 2 | toga village
# City not found. Skipping...
# Processing Record 6 of Set 2 | amungan
# Processing Record 7 of Set 2 | bilibino
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | west island
# Processing Record 12 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record
# Processing Record 33 of Set 3 | klyuchi
# Processing Record 34 of Set 3 | viransehir
# Processing Record 35 of Set 3 | port blair
# Processing Record 36 of Set 3 | holualoa
# Processing Record 37 of Set 3 | el granada
# Processing Record 38 of Set 3 | chonchi
# Processing Record 39 of Set 3 | mesolongi
# Processing Record 40 of Set 3 | qaqortoq
# Processing Record 41 of Set 3 | bhamo
# Processing Record 42 of Set 3 | meizhou
# Processing Record 43 of Set 3 | norresundby
# Processing Record 44 of Set 3 | aasiaat
# Processing Record 45 of Set 3 | kirakira
# Processing Record 46 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 47 of Set 3 | kill devil hills
# Processing Record 48 of Set 3 | weno
# Processing Record 49 of Set 3 | conception bay south
# Processing Record 0 of Set 4 | porto-vecchio
# Processing Record 1 of Set 4 | kapuskasing
# Processing Record 2 of Set 4 | tazovsky
# Processing Record 3 of Set 4 | ambon
# Processing Record 4 of Set 4 | north myrtle beach
# Processing Record 5 of Set 4 | luba
# Processing Record 6 of Set 4 | panama city beach
# Processing Record 7 of Set 4 | tobi village
# City not found. Skipping...
# Processing Record 8 of Set 4 | gewane
# Processing Record 9 of Set 4 | olyokminsk
# Processing Record 10 of Set 4 | east london
# Processing Record 11 of Set 4 | sept-iles
# Processing Record 12 of Set 4 | bako
# Processing Record 13 of Set 4 | san pedro de macoris
# Processing Record 14 of Set 4 | richards bay
# Processing Record 15 of Set 4 | enewetak
# Processing Record 16 of Set 4 | ta`u
# Processing Record 17 of Set 4 | oistins
# Processing Record 18 of Set 4 | amga
# Processing Record 19 of Set 4 | borogontsy
# Processing Record 20 of Set 4 | dhidhdhoo
# Processing Record 21 of Set 4 | crane
# Processing Record 22 of Set 4 | alexandria
# Processing Record 23 of Set 4 | halifax
# Processing Record 24 of Set 4 | papatowai
# Processing Record 25 of Set 4 | fontanelas
# Processing Record 26 of Set 4 | antsiranana
# Processing Record 27 of Set 4 | phan rang-thap cham
# Processing Record 28 of Set 4 | pisco
# Processing Record 29 of Set 4 | tazacorte
# Processing Record 30 of Set 4 | carnarvon
# Processing Record 31 of Set 4 | tual
# Processing Record 32 of Set 4 | malvan
# Processing Record 33 of Set 4 | bandarbeyla
# Processing Record 34 of Set 4 | siwa oasis
# Processing Record 35 of Set 4 | tandil
# Processing Record 36 of Set 4 | susuman
# Processing Record 37 of Set 4 | bontang
# Processing Record 38 of Set 4 | sandnessjoen
# Processing Record 39 of Set 4 | marsabit
# Processing Record 40 of Set 4 | vorgashor
# Processing Record 41 of Set 4 | maumere
# Processing Record 42 of Set 4 | la passe
# Processing Record 43 of Set 4 | tongchuanshi
# Processing Record 44 of Set 4 | hadibu
# Processing Record 45 of Set 4 | dunedin
# Processing Record 46 of Set 4 | baoshan
# Processing Record 47 of Set 4 | mugia
# Processing Record 48 of Set 4 | barra de santo antonio
# Processing Record 49 of Set 4 | ola
# Processing Record 0 of Set 5 | cabedelo
# Processing Record 1 of Set 5 | jumla
# Processing Record 2 of Set 5 | irymple
# Processing Record 3 of Set 5 | thunder bay
# Processing Record 4 of Set 5 | yellowknife
# Processing Record 5 of Set 5 | guercif
# Processing Record 6 of Set 5 | keflavik
# Processing Record 7 of Set 5 | inirida
# Processing Record 8 of Set 5 | akureyri
# Processing Record 9 of Set 5 | sydney
# Processing Record 10 of Set 5 | kemijarvi
# Processing Record 11 of Set 5 | aykhal
# Processing Record 12 of Set 5 | ilheus
# Processing Record 13 of Set 5 | kindu
# Processing Record 14 of Set 5 | strezhevoy
# Processing Record 15 of Set 5 | alta
# Processing Record 16 of Set 5 | perugorria
# Processing Record 17 of Set 5 | vidyayevo
# Processing Record 18 of Set 5 | ilulissat
# Processing Record 19 of Set 5 | ponta delgada
# Processing Record 20 of Set 5 | okha
# Processing Record 21 of Set 5 | apahida
# Processing Record 22 of Set 5 | kailua-kona
# Processing Record 23 of Set 5 | fisterra
# Processing Record 24 of Set 5 | champerico
# Processing Record 25 of Set 5 | faxinal
# Processing Record 26 of Set 5 | matasaru
# Processing Record 27 of Set 5 | rikaze
# Processing Record 28 of Set 5 | prince rupert
# Processing Record 29 of Set 5 | island harbour
# Processing Record 30 of Set 5 | mabaruma
# Processing Record 31 of Set 5 | howrah
# Processing Record 32 of Set 5 | wahpeton
# Processing Record 33 of Set 5 | kununurra
# Processing Record 34 of Set 5 | puerto baquerizo moreno
# Processing Record 35 of Set 5 | gornopravdinsk
# Processing Record 36 of Set 5 | vera cruz
# Processing Record 37 of Set 5 | stephenville
# Processing Record 38 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 39 of Set 5 | beira
# Processing Record 40 of Set 5 | sinabang
# Processing Record 41 of Set 5 | mount gambier
# Processing Record 42 of Set 5 | harar
# Processing Record 43 of Set 5 | bardai
# Processing Record 44 of Set 5 | la ronge
# Processing Record 45 of Set 5 | carolina
# Processing Record 46 of Set 5 | haiku-pauwela
# Processing Record 47 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 48 of Set 5 | taoudenni
# Processing Record 49 of Set 5 | bargara
# City not found. Skipping...
# Processing Record 0 of Set 6 | semnan
# Processing Record 1 of Set 6 | oppdal
# Processing Record 2 of Set 6 | egilsstadir
# Processing Record 3 of Set 6 | college
# Processing Record 4 of Set 6 | rio grande
# Processing Record 5 of Set 6 | tai'an
# Processing Record 6 of Set 6 | tahoua
# Processing Record 7 of Set 6 | pimentel
# Processing Record 8 of Set 6 | ungsang-nodongjagu
# Processing Record 9 of Set 6 | rychnov nad kneznou
# Processing Record 10 of Set 6 | arawa
# Processing Record 11 of Set 6 | hassi messaoud
# Processing Record 12 of Set 6 | nar'yan-mar
# Processing Record 13 of Set 6 | sepatan
# Processing Record 14 of Set 6 | monteagudo
# Processing Record 15 of Set 6 | ketou
# Processing Record 16 of Set 6 | mount pearl
# Processing Record 17 of Set 6 | kataragama
# City not found. Skipping...
# Processing Record 18 of Set 6 | cerkes
# Processing Record 19 of Set 6 | cockburn town
# Processing Record 20 of Set 6 | choibalsan
# Processing Record 21 of Set 6 | smithers
# Processing Record 22 of Set 6 | iskateley
# Processing Record 23 of Set 6 | sao vicente
# Processing Record 24 of Set 6 | kapa'a
# Processing Record 25 of Set 6 | karystos
# Processing Record 26 of Set 6 | canutama
# Processing Record 27 of Set 6 | chibougamau
# Processing Record 28 of Set 6 | souillac
# Processing Record 29 of Set 6 | ust-tsilma
# Processing Record 30 of Set 6 | tezu
# Processing Record 31 of Set 6 | kuanda
# Processing Record 32 of Set 6 | coahuayana de hidalgo
# Processing Record 33 of Set 6 | pathein
# Processing Record 34 of Set 6 | odzak
# Processing Record 35 of Set 6 | nicoya
# Processing Record 36 of Set 6 | loen
# Processing Record 37 of Set 6 | margate
# Processing Record 38 of Set 6 | okhotsk
# Processing Record 39 of Set 6 | carrizo springs
# Processing Record 40 of Set 6 | rundu
# Processing Record 41 of Set 6 | bongao
# Processing Record 42 of Set 6 | dudinka
# Processing Record 43 of Set 6 | hammerfest
# Processing Record 44 of Set 6 | andkhoy
# Processing Record 45 of Set 6 | sibundoy
# Processing Record 46 of Set 6 | plettenberg bay
# Processing Record 47 of Set 6 | siguiri
# Processing Record 48 of Set 6 | wynyard
# Processing Record 49 of Set 6 | ikalamavony
# Processing Record 0 of Set 7 | vila velha
# Processing Record 1 of Set 7 | firuzabad
# Processing Record 2 of Set 7 | port saint john's
# Processing Record 3 of Set 7 | ust-nera
# Processing Record 4 of Set 7 | san leone mose
# City not found. Skipping...
# Processing Record 5 of Set 7 | cannonvale
# Processing Record 6 of Set 7 | antalaha
# Processing Record 7 of Set 7 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 8 of Set 7 | dryden
# Processing Record 9 of Set 7 | grand falls-windsor
# Processing Record 10 of Set 7 | las cruces
# Processing Record 11 of Set 7 | minas de marcona
# Processing Record 12 of Set 7 | hanceville
# Processing Record 13 of Set 7 | san juan
# Processing Record 14 of Set 7 | shenjiamen
# Processing Record 15 of Set 7 | la'ie
# Processing Record 16 of Set 7 | pacocha
# Processing Record 17 of Set 7 | queenstown
# Processing Record 18 of Set 7 | jining
# Processing Record 19 of Set 7 | vilyuysk
# Processing Record 20 of Set 7 | galle
# Processing Record 21 of Set 7 | mariental
# Processing Record 22 of Set 7 | padang
# Processing Record 23 of Set 7 | ploneour-lanvern
# Processing Record 24 of Set 7 | hithadhoo
# Processing Record 25 of Set 7 | linden
# Processing Record 26 of Set 7 | revda
# Processing Record 27 of Set 7 | ismayilli
# Processing Record 28 of Set 7 | onguday
# Processing Record 29 of Set 7 | campillos
# Processing Record 30 of Set 7 | doba
# Processing Record 31 of Set 7 | salair
# Processing Record 32 of Set 7 | limon
# Processing Record 33 of Set 7 | chamical
# Processing Record 34 of Set 7 | wuhai
# Processing Record 35 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 36 of Set 7 | winkler
# Processing Record 37 of Set 7 | arraial do cabo
# Processing Record 38 of Set 7 | lerwick
# Processing Record 39 of Set 7 | hami
# Processing Record 40 of Set 7 | tsiombe
# Processing Record 41 of Set 7 | nemuro
# Processing Record 42 of Set 7 | broken hill
# Processing Record 43 of Set 7 | ilomantsi
# Processing Record 44 of Set 7 | chom thong
# Processing Record 45 of Set 7 | selfoss
# Processing Record 46 of Set 7 | mount isa
# Processing Record 47 of Set 7 | san luis de la loma
# Processing Record 48 of Set 7 | huron
# Processing Record 49 of Set 7 | nova sintra
# Processing Record 0 of Set 8 | guiuan
# Processing Record 1 of Set 8 | nagqu
# Processing Record 26 of Set 9 | shizuishan
# Processing Record 27 of Set 9 | uturoa
# Processing Record 28 of Set 9 | ratnagiri
# Processing Record 29 of Set 9 | upington
# Processing Record 30 of Set 9 | estes park
# Processing Record 31 of Set 9 | luanda
# Processing Record 32 of Set 9 | awjilah
# Processing Record 33 of Set 9 | birao
# Processing Record 34 of Set 9 | mahina
# Processing Record 35 of Set 9 | kalmunai
# Processing Record 36 of Set 9 | kabinda
# Processing Record 37 of Set 9 | jiuquan
# Processing Record 38 of Set 9 | daugavpils
# Processing Record 39 of Set 9 | montepuez
# Processing Record 40 of Set 9 | undurkhaan
# Processing Record 41 of Set 9 | balatonboglar
# Processing Record 42 of Set 9 | arak
# Processing Record 43 of Set 9 | sarakhs
# Processing Record 44 of Set 9 | nizhneangarsk
# Processing Record 45 of Set 9 | jagatsinghapur
# Processing Record 46 of Set 9 | hobyo
# Processing Record 47 of Set 9 | usogorsk
# Processing Record 48 of Set 9 | huarmey
# Processing Record 49 of Set 9 | chegdomyn
# Processing Record 0 of Set 10 | beyneu
# Processing Record 1 of Set 10 | fort-shevchenko
# Processing Record 2 of Set 10 | onega
# Processing Record 3 of Set 10 | beykonak
# Processing Record 4 of Set 10 | arkhangel'sk
# Processing Record 5 of Set 10 | 'ain el hadjar
# Processing Record 6 of Set 10 | ubinskoye
# Processing Record 7 of Set 10 | bafoulabe
# Processing Record 8 of Set 10 | san sebastian de la gomera
# Processing Record 9 of Set 10 | ciudad constitucion
# Processing Record 10 of Set 10 | geraldton
# Processing Record 11 of Set 10 | ras gharib
# City not found. Skipping...
# Processing Record 12 of Set 10 | balqash
# Processing Record 13 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 14 of Set 10 | sao joao da barra
# Processing Record 15 of Set 10 | howard springs
# Processing Record 16 of Set 10 | nadym
# Processing Record 17 of Set 10 | muisne
# Processing Record 18 of Set 10 | cable beach
# City not found. Skipping...
# Processing Record 19 of Set 10 | tralee
# Processing Record 20 of Set 10 | dalandzadgad
# Processing Record 21 of Set 10 | colonia
# Processing Record 22 of Set 10 | elsterwerda
# Processing Record 23 of Set 10 | harper
# Processing Record 24 of Set 10 | balcarce
# Processing Record 25 of Set 10 | roccella ionica
# Processing Record 26 of Set 10 | jerantut
# Processing Record 27 of Set 10 | burang
# Processing Record 28 of Set 10 | saint-pierre
# Processing Record 29 of Set 10 | kibakwe
# Processing Record 30 of Set 10 | el calafate
# Processing Record 31 of Set 10 | nguigmi
# Processing Record 32 of Set 10 | kruisfontein
# Processing Record 33 of Set 10 | bardsir
# Processing Record 34 of Set 10 | rayside-balfour
# City not found. Skipping...
# Processing Record 35 of Set 10 | ghatanji
# Processing Record 36 of Set 10 | khodzha-maston
# Processing Record 37 of Set 10 | laojunmiao
# Processing Record 38 of Set 10 | lyuban'
# Processing Record 39 of Set 10 | espargos
# City not found. Skipping...
# Processing Record 40 of Set 10 | cole harbour
# Processing Record 41 of Set 10 | lukolela
# Processing Record 42 of Set 10 | karratha
# Processing Record 43 of Set 10 | talara
# Processing Record 44 of Set 10 | khandyga
# Processing Record 45 of Set 10 | fada
# Processing Record 46 of Set 10 | nago
# Processing Record 47 of Set 10 | box elder
# Processing Record 48 of Set 10 | corumba
# Processing Record 49 of Set 10 | uyovu
# Processing Record 0 of Set 11 | alo
# Processing Record 1 of Set 11 | nyurba
# Processing Record 2 of Set 11 | murashi
# Processing Record 3 of Set 11 | moussoro
# Processing Record 4 of Set 11 | urzhar
# Processing Record 5 of Set 11 | anar darah
# Processing Record 6 of Set 11 | cabo san lucas
# Processing Record 7 of Set 11 | tofol
# Processing Record 8 of Set 11 | rossleben
# Processing Record 9 of Set 11 | port isabel
# Processing Record 10 of Set 11 | petoskey
# Processing Record 11 of Set 11 | hailar
# Processing Record 12 of Set 11 | santyoku
# Processing Record 13 of Set 11 | nizhneudinsk
# Processing Record 14 of Set 11 | morteros
# Processing Record 15 of Set 11 | santa cruz
# Processing Record 16 of Set 11 | solnechnyy
# Processing Record 17 of Set 11 | springbok
# Processing Record 18 of Set 11 | hiratacho
# Processing Record 19 of Set 11 | katsuren-haebaru
# Processing Record 20 of Set 11 | ghat
# Processing Record 21 of Set 11 | peniche
# Processing Record 22 of Set 11 | dalbandin
# Processing Record 23 of Set 11 | fray luis beltran
# Processing Record 24 of Set 11 | sydney mines
# Processing Record 25 of Set 11 | santo antonio do ica
# Processing Record 26 of Set 11 | alofi
# Processing Record 27 of Set 11 | osakarovka
# Processing Record 28 of Set 11 | acapulco de juarez
# Processing Record 29 of Set 11 | vrchlabi
# Processing Record 30 of Set 11 | deir ez-zor
# Processing Record 31 of Set 11 | tocopilla
# Processing Record 32 of Set 11 | french rocks
# Processing Record 33 of Set 11 | el nido
# Processing Record 34 of Set 11 | kiunga
# Processing Record 35 of Set 11 | kure
# Processing Record 36 of Set 11 | justiniano posse
# Processing Record 37 of Set 11 | ariquemes
# Processing Record 38 of Set 11 | coronel dorrego
# Processing Record 39 of Set 11 | diu
# Processing Record 40 of Set 11 | alice springs
# Processing Record 41 of Set 11 | al hasaheisa
# Processing Record 42 of Set 11 | idrinskoye
# Processing Record 43 of Set 11 | gebeit
# Processing Record 44 of Set 11 | 'ohonua
# City not found. Skipping...
# Processing Record 45 of Set 11 | kingston
# Processing Record 46 of Set 11 | binji
# Processing Record 47 of Set 11 | malanje
# Processing Record 48 of Set 11 | tevriz
# Processing Record 49 of Set 11 | monte cristo
# Processing Record 0 of Set 12 | ha'il
# Processing Record 1 of Set 12 | bantay
# Processing Record 2 of Set 12 | costa calma
# City not found. Skipping...
# Processing Record 3 of Set 12 | bloomfield
# Processing Record 4 of Set 12 | benghazi
# Processing Record 5 of Set 12 | kovalam
# Processing Record 6 of Set 12 | aral
# Processing Record 7 of Set 12 | san giovanni in fiore
# Processing Record 8 of Set 12 | lebanon
# Processing Record 9 of Set 12 | lamar
# Processing Record 10 of Set 12 | summerside
# Processing Record 11 of Set 12 | inhambane
# Processing Record 12 of Set 12 | broome
# Processing Record 13 of Set 12 | karangampel
# Processing Record 14 of Set 12 | mamuju
# Processing Record 15 of Set 12 | kyren
# Processing Record 16 of Set 12 | al jawf
# Processing Record 17 of Set 12 | tadine
# Processing Record 18 of Set 12 | kettering
# Processing Record 19 of Set 12 | devinuwara
# City not found. Skipping...
# Processing Record 20 of Set 12 | nizhniy kuranakh
# Processing Record 21 of Set 12 | yaren
# Processing Record 22 of Set 12 | nchelenge
# Processing Record 23 of Set 12 | lijiang
# Processing Record 24 of Set 12 | bela
# Processing Record 25 of Set 12 | kuchinarai
# Processing Record 26 of Set 12 | kachug
# Processing Record 27 of Set 12 | flin flon
# Processing Record 28 of Set 12 | saguenay
# Processing Record 29 of Set 12 | xai-xai
# Processing Record 30 of Set 12 | kavaratti
# Processing Record 31 of Set 12 | domingos martins
# Processing Record 32 of Set 12 | demopolis
# Processing Record 33 of Set 12 | winona
# Processing Record 34 of Set 12 | dwarka
# Processing Record 35 of Set 12 | igarka
# Processing Record 36 of Set 12 | afonso claudio
# Processing Record 37 of Set 12 | rakops
# Processing Record 38 of Set 12 | new norfolk
# Processing Record 39 of Set 12 | galliano
# Processing Record 40 of Set 12 | mafinga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          569
# Lat           569
# Lng           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# Country       569
# Date          569
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      adamstown -25.0660 -130.1015     21.65        72         100
# 1       el bauga  18.2620   33.9081     26.66        52           0
# 2         bykovo  55.6361   38.0803      0.85        86          75
# 3      arlington  32.7357  -97.1081     25.15        48           0
# 4  ploudalmezeau  48.5333   -4.6500     11.21        93         100
#
#    Wind Speed Country        Date
# 0        4.33      PN  1731447614
# 1        3.29      SD  1731447615
# 2        3.00      RU  1731447617
# 3        3.60      US  1731447618
# 4        7.20      FR  1731447619

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Export the City_Data into a csv
# ----> 2 city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'output_data'

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat'].astype("float")
y_values = city_data_df['Max Temp'].astype("float")
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat'].astype("float")
y_values = city_data_df['Humidity'].astype("float")
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidiy (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat'].astype("float")
y_values = city_data_df['Cloudiness'].astype("float")
plt.scatter(x_values,y_values)


# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat'].astype("float")
y_values = city_data_df['Wind Speed'].astype("float")
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_regress_plot (x_values, y_values, y_axis):
    
    # Run linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot scatter plot
    plt.scatter(x_values,y_values)
    
    # Set x coordinates for model's formula 
    if x_values.sum() > 0:
        x_coord = 5
    else:
        x_coord = -50
    
    # Plot regression line
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(x_coord,10),fontsize=18,color="red")
    
    # Label plot
    plt.xlabel('Latitude')
    plt.ylabel(y_axis)
    
    # Print r square value
    print(f"The r-value is: {rvalue}")

    # Show plot
    return plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>= 0]

# Display sample data
northern_hemi_df.head()

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']< 0]

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
y_axis = 'Max Temperature'

lin_regress_plot(x_values,y_values, y_axis)

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
y_axis = 'Max Temperature'

lin_regress_plot(x_values,y_values, y_axis)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
y_axis = 'Humidity'

lin_regress_plot(x_values,y_values, y_axis)

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
y_axis = 'Humidity'

lin_regress_plot(x_values,y_values, y_axis)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
y_axis = 'Cloudiness'

lin_regress_plot(x_values,y_values, y_axis)

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
y_axis = 'Cloudiness'

lin_regress_plot(x_values,y_values, y_axis)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
y_axis = 'Wind Speed'

lin_regress_plot(x_values,y_values, y_axis)

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
y_axis = 'Wind Speed'

lin_regress_plot(x_values,y_values, y_axis)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
